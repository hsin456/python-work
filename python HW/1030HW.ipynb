# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sympy as sp

# %%
df = pd.read_csv('https://opendata.epa.gov.tw/ws/Data/ATM00625/?$format=csv')

# %%
df #各地的數值
# Out:
#    Site county  PM25  DataCreationDate ItemUnit
# 0    崙背    雲林縣   104  2019-11-12 21:00    μg/m3
# 1   富貴角    新北市    23  2019-11-12 21:00    μg/m3
# 2    麥寮    雲林縣    31  2019-11-12 21:00    μg/m3
# 3    關山    臺東縣    23  2019-11-12 21:00    μg/m3
# 4    馬公    澎湖縣    29  2019-11-12 21:00    μg/m3
# 5    金門    金門縣    37  2019-11-12 21:00    μg/m3
# 6    馬祖    連江縣    27  2019-11-12 21:00    μg/m3
# 7    埔里    南投縣    50  2019-11-12 21:00    μg/m3
# 8    復興    高雄市    16  2019-11-12 21:00    μg/m3
# 9    永和    新北市    22  2019-11-12 21:00    μg/m3
# 10   竹山    南投縣    55  2019-11-12 21:00    μg/m3
# 11   中壢    桃園市    30  2019-11-12 21:00    μg/m3
# 12   三重    新北市    23  2019-11-12 21:00    μg/m3
# 13   冬山    宜蘭縣    25  2019-11-12 21:00    μg/m3
# 14   宜蘭    宜蘭縣    29  2019-11-12 21:00    μg/m3
# 15   陽明    臺北市    18  2019-11-12 21:00    μg/m3
# 16   花蓮    花蓮縣    27  2019-11-12 21:00    μg/m3
# 17   臺東    臺東縣    20  2019-11-12 21:00    μg/m3
# 18   恆春    屏東縣    20  2019-11-12 21:00    μg/m3
# ...

# %% [markdown]
# ### PM2.5最高的前五個

# %%
df.sort_values(by = 'PM25', ascending = False).head()
# Out:
#    Site county  PM25  DataCreationDate ItemUnit
# 0    崙背    雲林縣   104  2019-11-12 21:00    μg/m3
# 39   新港    嘉義縣    71  2019-11-12 21:00    μg/m3
# 33   安南    臺南市    61  2019-11-12 21:00    μg/m3
# 38   朴子    嘉義縣    59  2019-11-12 21:00    μg/m3
# 41   斗六    雲林縣    56  2019-11-12 21:00    μg/m3

# %%
df2 = pd.read_csv('https://opendata.epa.gov.tw/ws/Data/AQI/?$format=csv')

# %%
df2.head()
# Out:
#     SiteName County  AQI Pollutant    Status  SO2    CO  CO_8hr  O3  O3_8hr  \
# 0  桃園(觀音工業區)    桃園市   82     細懸浮微粒        普通  2.2  0.24     0.2  37    48.0
# 1     屏東(琉球)    屏東縣  146     臭氧八小時  對敏感族群不健康  2.6  0.22     0.3  77    84.0
# 2     新竹(香山)    新竹市   84     細懸浮微粒        普通  1.5  0.55     0.4  20    51.0
# 3     彰化(大城)    彰化縣  172     臭氧八小時  對所有族群不健康  1.9  0.29     0.3  71    94.0
# 4     臺南(麻豆)    臺南市  109     細懸浮微粒  對敏感族群不健康  2.2  0.74     0.4  37    73.0
#
#    ...   NO  WindSpeed  WindDirec       PublishTime  PM2.5_AVG  PM10_AVG  \
# 0  ...  0.6        0.9       70.0  2019-11-12 22:00         28        62
# 1  ...  0.7        0.3      199.0  2019-11-12 22:00         25        45
# 2  ... -0.2        0.3      126.0  2019-11-12 22:00         29        56
# 3  ...  0.7        0.0        0.0  2019-11-12 22:00         28        65
# 4  ...  1.0        1.2       75.0  2019-11-12 22:00         39        76
#
#    SO2_AVG   Longitude   Latitude  SiteId
# ...

# %% [markdown]
# ### PM2.5平均最高的前五個

# %%
df2.sort_values(by = 'PM2.5_AVG' , ascending = False).head()
# Out:
#    SiteName County  AQI Pollutant    Status  SO2    CO  CO_8hr  O3  O3_8hr  \
# 44       崙背    雲林縣  166     細懸浮微粒  對所有族群不健康  1.4  0.72     0.6  18    70.0
# 43       新港    嘉義縣  156     細懸浮微粒  對所有族群不健康  2.9  0.65     0.5  37    78.0
# 14       竹山    南投縣  138     細懸浮微粒  對敏感族群不健康  2.4  0.52     0.5  48    78.0
# 45       斗六    雲林縣  136     細懸浮微粒  對敏感族群不健康  2.3  0.59     0.5  45    74.0
# 42       朴子    嘉義縣  131     細懸浮微粒  對敏感族群不健康  2.0  0.73     0.5  44    79.0
#
#     ...   NO  WindSpeed  WindDirec       PublishTime  PM2.5_AVG  PM10_AVG  \
# 44  ...  1.8        0.4      254.0  2019-11-12 22:00         83       137
# 43  ...  0.5        0.5      106.0  2019-11-12 22:00         64       112
# 14  ...  0.7        0.5      335.0  2019-11-12 22:00         50        79
# 45  ...  1.7        1.5      123.0  2019-11-12 22:00         49        88
# 42  ...  1.3        0.5       87.0  2019-11-12 22:00         47        88
#
#     SO2_AVG   Longitude   Latitude  SiteId
# ...
