# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## 桃園國際機場捷運全線里程及路線資料

# %%
df = pd.read_csv('https://www.rb.gov.tw/public/files/artsinfo/1550198991-0.csv')

# %%
df
# Out:
#         結構類型     站間里程     開始里程         連續里程          長度m         備註  \
# 0       地下路段  0+000.0  0+000.0   64+082.418        #REF!         起點
# 1       地下路段  0+010.0  0+010.0   64+092.418        #REF!        NaN
# 2       地下路段  0+020.0  0+020.0   64+102.418        #REF!        NaN
# 3       地下路段  0+030.0  0+030.0   64+112.418        #REF!        NaN
# 4       地下路段  0+040.0  0+040.0   64+122.418        #REF!        NaN
# 5       地下路段  0+050.0      NaN   64+132.418  2350.00000         NaN
# 6       地下路段  0+060.0      NaN   64+142.418          NaN        NaN
# 7       地下路段  0+070.0      NaN   64+152.418          NaN        NaN
# 8       地下路段  0+080.0      NaN   64+162.418          NaN        NaN
# 9       地下路段  0+090.0      NaN   64+172.418          NaN        NaN
# 10      地下路段  0+100.0      NaN   64+182.418          NaN        NaN
# 11      地下路段  0+110.0      NaN   64+192.418          NaN        NaN
# 12      地下車站  0+000.0    #REF!   64+196.120    10.00000    A1(台北車站)
# ...

# %%
df_sorted1=df1

# %%
df1 = df_sorted1[df_sorted1.結構類型=='地下路段']

# %%
df1
# Out:
#       結構類型     站間里程     開始里程         連續里程          長度m   備註         座標N值  \
# 0     地下路段  0+000.0  0+000.0   64+082.418        #REF!   起點  2771253.956
# 1     地下路段  0+010.0  0+010.0   64+092.418        #REF!  NaN  2771256.457
# 2     地下路段  0+020.0  0+020.0   64+102.418        #REF!  NaN  2771258.958
# 3     地下路段  0+030.0  0+030.0   64+112.418        #REF!  NaN  2771261.459
# 4     地下路段  0+040.0  0+040.0   64+122.418        #REF!  NaN  2771263.960
# 5     地下路段  0+050.0      NaN   64+132.418  2350.00000   NaN  2771266.461
# 6     地下路段  0+060.0      NaN   64+142.418          NaN  NaN  2771268.963
# 7     地下路段  0+070.0      NaN   64+152.418          NaN  NaN  2771271.464
# 8     地下路段  0+080.0      NaN   64+162.418          NaN  NaN  2771273.965
# 9     地下路段  0+090.0      NaN   64+172.418          NaN  NaN  2771276.466
# 10    地下路段  0+100.0      NaN   64+182.418          NaN  NaN  2771278.967
# 11    地下路段  0+110.0      NaN   64+192.418          NaN  NaN  2771281.468
# ...

# %%
df2=df1[["站間里程"]]

# %%
df2.sum(axis=1)
# Out:
# 0       0+000.0
# 1       0+010.0
# 2       0+020.0
# 3       0+030.0
# 4       0+040.0
# 5       0+050.0
# 6       0+060.0
# 7       0+070.0
# 8       0+080.0
# 9       0+090.0
# 10      0+100.0
# 11      0+110.0
# 13      0+010.0
# 14      0+020.0
# 15      0+030.0
# 16      0+040.0
# 17      0+050.0
# 18      0+060.0
# 19      0+070.0
# 20      0+080.0
# 21      0+090.0
# 22      0+100.0
# 23      0+110.0
# 24      0+120.0
# 25      0+130.0
# 26      0+140.0
# 27      0+150.0
# 28      0+160.0
# 29      0+170.0
# 30      0+180.0
#          ...
# 5087    1+340.0
# 5088    1+350.0
# 5089    1+360.0
# 5090    1+370.0
# 5091    1+380.0
# 5092    1+390.0
# 5093    1+400.0
# 5094    1+410.0
# 5095    1+420.0
# 5096    1+430.0
# 5097    1+440.0
# 5098    1+450.0
# 5099    1+460.0
# 5100    1+470.0
# 5101    1+480.0
# 5102    1+490.0
# 5103    1+500.0
# 5104    1+510.0
# 5105    1+520.0
# 5106    1+530.0
# 5108    0+010.0
# 5109    0+020.0
# 5110    0+030.0
# 5111    0+040.0
# ...

# %% [markdown]
# ## 地下路段總長1089

# %%
df3 = pd.read_csv('https://www.rb.gov.tw/public/files/artsinfo/1550198991-0.csv')

# %%
df3
# Out:
#         結構類型     站間里程     開始里程         連續里程          長度m         備註  \
# 0       地下路段  0+000.0  0+000.0   64+082.418        #REF!         起點
# 1       地下路段  0+010.0  0+010.0   64+092.418        #REF!        NaN
# 2       地下路段  0+020.0  0+020.0   64+102.418        #REF!        NaN
# 3       地下路段  0+030.0  0+030.0   64+112.418        #REF!        NaN
# 4       地下路段  0+040.0  0+040.0   64+122.418        #REF!        NaN
# 5       地下路段  0+050.0      NaN   64+132.418  2350.00000         NaN
# 6       地下路段  0+060.0      NaN   64+142.418          NaN        NaN
# 7       地下路段  0+070.0      NaN   64+152.418          NaN        NaN
# 8       地下路段  0+080.0      NaN   64+162.418          NaN        NaN
# 9       地下路段  0+090.0      NaN   64+172.418          NaN        NaN
# 10      地下路段  0+100.0      NaN   64+182.418          NaN        NaN
# 11      地下路段  0+110.0      NaN   64+192.418          NaN        NaN
# 12      地下車站  0+000.0    #REF!   64+196.120    10.00000    A1(台北車站)
# ...

# %%
df_sorted3=df3

# %%
df3 = df_sorted3[df_sorted3.結構類型=='高架路段']

# %%
df3
# Out:
#       結構類型     站間里程 開始里程         連續里程    長度m   備註         座標N值        座標E值  \
# 255   高架路段  2+420.0  NaN   66+616.120  #REF!  NaN  2771615.956  299761.854
# 256   高架路段  2+430.0  NaN   66+626.120  #REF!  NaN  2771609.157  299754.521
# 257   高架路段  2+440.0  NaN   66+636.120  #REF!  NaN  2771602.358  299747.188
# 258   高架路段  2+450.0  NaN   66+646.120  #REF!  NaN  2771595.559  299739.855
# 259   高架路段  2+460.0  NaN   66+656.120  #REF!  NaN  2771588.760  299732.522
# 260   高架路段  2+470.0  NaN   66+666.120  #REF!  NaN  2771581.961  299725.188
# 261   高架路段  2+480.0  NaN   66+676.120  #REF!  NaN  2771575.162  299717.855
# 262   高架路段  2+490.0  NaN   66+686.120  #REF!  NaN  2771568.363  299710.522
# 263   高架路段  2+500.0  NaN   66+696.120  #REF!  NaN  2771561.564  299703.189
# 264   高架路段  2+510.0  NaN   66+706.120  #REF!  NaN  2771554.765  299695.856
# 265   高架路段  2+520.0  NaN   66+716.120  #REF!  NaN  2771547.966  299688.523
# ...

# %%
df4=df3[["站間里程"]]

# %%
df4.sum(axis=1)
# Out:
# 255     2+420.0
# 256     2+430.0
# 257     2+440.0
# 258     2+450.0
# 259     2+460.0
# 260     2+470.0
# 261     2+480.0
# 262     2+490.0
# 263     2+500.0
# 264     2+510.0
# 265     2+520.0
# 266     2+530.0
# 267     2+540.0
# 268     2+550.0
# 269     2+560.0
# 270     2+570.0
# 271     2+580.0
# 272     2+590.0
# 273     2+600.0
# 274     2+610.0
# 275     2+620.0
# 276     2+630.0
# 277     2+640.0
# 278     2+650.0
# 279     2+660.0
# 280     2+670.0
# 281     2+680.0
# 282     2+690.0
# 283     2+700.0
# 284     2+710.0
#          ...
# 4998    0+450.0
# 4999    0+460.0
# 5000    0+470.0
# 5001    0+480.0
# 5002    0+490.0
# 5003    0+500.0
# 5004    0+510.0
# 5005    0+520.0
# 5006    0+530.0
# 5007    0+540.0
# 5008    0+550.0
# 5009    0+560.0
# 5010    0+570.0
# 5011    0+580.0
# 5012    0+590.0
# 5013    0+600.0
# 5014    0+610.0
# 5015    0+620.0
# 5016    0+630.0
# 5017    0+640.0
# 5018    0+650.0
# 5019    0+660.0
# 5020    0+670.0
# 5021    0+680.0
# ...

# %% [markdown]
# ##  高架路段總長3919
