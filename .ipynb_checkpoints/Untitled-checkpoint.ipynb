# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
x=[1,2.8,5.6]

# %%
plt.plot(x)

# %%
x=[4,5,6]
y=[0.1,2.7,10]

# %%
plt.plot(x,y)

# %%
np.cos(x)
# Out:
# array([-0.65364362,  0.28366219,  0.96017029])

# %%
x=np.sin(x)

# %%
plt.plot(x)
